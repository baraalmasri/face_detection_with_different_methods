# %%
from matplotlib import pyplot as plt
import numpy as np
import face_recognition

# %%
fotograf_1 = plt.imread('C:\\Users\\bero\\Desktop\\test2.jpg')
plt.imshow(fotograf_1)

# %%
foto = face_recognition.load_image_file('C:\\Users\\bero\\Desktop\\test2.jpg')

# %%
yuz_konumlari = face_recognition.face_locations(foto)

# %%
yuz_konumlari
# Out:
# [(869, 1508, 2019, 357)]

# %%
ust, sag, alt, sol = yuz_konumlari[0]
yuz_2 = foto[ust:alt , sol:sag]
plt.imshow(yuz_2)
