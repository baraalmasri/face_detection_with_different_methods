# %%
from matplotlib import pyplot as plt
import cv2
import numpy as np
import face_recognition
fotograf_1 = plt.imread('C:\\Users\\bero\\Desktop\\test3.jpg')
plt.imshow(fotograf_1)
foto = face_recognition.load_image_file('C:\\Users\\bero\\Desktop\\test3.jpg')
yuz_konumlari = face_recognition.face_locations(foto)

# %%
ust, sag, alt, sol = yuz_konumlari[0]
yuz_konumlari  # yuzun oldugu yer noktalari
# Out:
# [(116, 236, 270, 81)]

# %%
#birinci sekili yuzu kesip ayiri bir fotograf kayidetmek icin yararli 
yuz_2 = foto[ust:alt , sol:sag]
plt.imshow(yuz_2)

# %%
# ikinci sekili yuzu kare cismek icin (buna yapabilmek icin cv2 kutuphanesi import etmek gerekir)
m , n,p= foto.shape 
for  m in range (foto.shape[0]):
    for n in range(foto.shape[1]):
            #  yuzu kare cizme
            cv2.rectangle(foto, (sol-10, ust-10), (sag+10, alt+10), (255, 0, 0), 2)

# %%
plt.imshow(foto)
